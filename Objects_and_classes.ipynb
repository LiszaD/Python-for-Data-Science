# %% [markdown]
# You have been recruited by your friend, a linguistics enthusiast, to create a utility tool that can perform analysis on a given piece of text. Complete the class
# 'analysedText' with the following methods -
#
# <ul>
#     <li> Constructor (__init__) - This method should take the argument <code>text</code>, make it lower case, and remove all punctuation.  Assume only the following punctuation is used: period (.), exclamation mark (!), comma (,) and question mark (?). Assign this newly formatted text to a new attribute called <code>fmtText</code>.
#     <li> freqAll - This method should create and <strong>return</strong> dictionary of all unique words in the text, along with the number of times they occur in the text. Each key in the dictionary should be the unique word appearing in the text and the associated value should be the number of times it occurs in the text. Create this dictionary from the <code>fmtText</code> attribute.
#     <li> freqOf - This method should take a word as an argument and <strong>return</strong> the number of occurrences of that word in <code>fmtText</code>.
# </ul>
#  The skeleton code has been given to you. Docstrings can be ignored for the purpose of the exercise. <br>
#  <i> Hint: Some useful functions are <code>replace()</code>, <code>lower()</code>, <code>split()</code>, <code>count()</code> </i><br>

# %%
import string


class analysedText(object):
    
    def __init__ (self, text):

        # punctuation = '.!,?'
        self.text = text
        # text.lower.split()
        self.text = text.translate(str.maketrans(text, string.punctuation))
        fmtText = text
        
fmtText = analysedText()
      
        # TODO: Remove the punctuation from <text> and make it lower case.

        # TODO: Assign the formatted text to a new attribute called "fmtText"
        
def freqAll(self):    

        # TODO: Split the text into a list of words  

        # TODO: Create a dictionary with the unique words in the text as keys
        # and the number of times they occur in the text as values
      
        pass # return the created dictionary
    
def freqOf(self, word):

        # TODO: return the number of occurrences of <word> in <fmtText>

        pass

# %%
import string

This_is_a_test = "hello, my name! What could it be? How do I answer, answer, answer, this?"

class analysedText():
    
    def __init__ (self, text):

        punctuation = "'.!,?"
        self.text = text.lower
        self.text = This_is_a_test.translate(str.maketrans(",", string.punctuation))
        return(self.text)

print(This_is_a_test)

# %% [markdown]
# Objects and Classes lecture
#
# - python has lots of data types
# - types: int: 1, float: 1.2, string: 'aah hi', list: [1, 2, 'abc'], dictionary: {"dog":1, "Cat":2}, Bool: False, True
# - each is an object
# - every object has:
#     - a type
#     - an internal data representation (a blueprint)
#     - a set of procedures for interacting with the object (methods)
# - an object is an instance of a particular type
# - eg.   1. Type 1 --> can have several objects of type 1 (object 1, object 2, object 3, object 4, etc.)....each object is an instance of type 1
#         2. Type 2 --> can have several objects of type 2 (object 1, object 2, object 3, object 4, etc.)....each object is an instance of type 2
# - a (class or type's) methods are functions that every instance of that class or type provides; it's how you interact with the data in an object
#     - eg. sorting is a method that interacts with the data in the object:
#             Ratings = [5,6,3,10,3]
#             Ratings.sort        # will sort the data in Ratings (the object) from low to high
#             Output: [3,3,5,6,10]
#     - eg. reverse sorting (use above ratings list)
#             Ratings.reverse
#             Output: [10,6,5,3,3]
#
#
# Remember: Class and type are the same

# %%
# can find the type of object using command type()

type([1, 34, 3])

# returns: list; the object is an instance of type list

type(1)

# returns: int; the object is an instance of type integer

# %% [markdown]
# Creating a class
#
# - A class has:
#     1. data attributes --> these define the class
#     2. Methods
# - then create objects or instances of that class
#
# Class (contains: data attributes, methods)---> Object 1, Object 2, Object3, Object4, Object5
#
# # eg.
# # class = class definition
# # Circle = name of Class
# # object = class parent ----> only use 'object' for this course
#
# Eg.
#
# # Class Circle
# # Data attributes: radius, color
# # (use a color to make it easier to distinguish classes later)
#
# # This defines your class
# class Circle(object):
#
#     def_init_(self, radius, color):                     # the 'def_init_' --> the function 'init' is a special method or constructor used to initialize data attributes
#         self.radius = radius;                           # the 'self' parameter refers to the newly created instance of the class
#         self.color = color;
#
# C1 = Circle(10,"red")
# C1.radius                                        # gives the radius
# C1.color                                         # gives you the color
# C1.color = "blue"                                # can use this to change the parameter color to blue
# C1.color                                         # to confirm the circle is now blue
#
#         # the parameters (self, radius, color), radius, and color can be used in the constructor's body to access values of the radius and color data attributes to the values passed to the constructor method
#         # after you create your class, need to in order to create an object of class circle, we introduce a variable (or the name of the object)
#
#
#
# # Below the class are the data attributes that are used to initialize each instance of the class
#     # Object 1: instance of type circle; data attributes: radius = 4, color = red
#     # Object 2: instance of type circle; data attributes: radius = 2, color = green
#
# # Note: there are other special functions in python to make more complex classes
# # Think of self as a box that contains all the data attributes of the object
#
#
#
# # Class Rectangle
# # Data attributes: width, length, color
#
# class Rectangle(object):
#
#     def_init_(self,color,height,width):
#         self.height = height;
#         self.width = width;
#         self.color = color;
#
# Object 1: instance of type rectangle; data attributes: height = 2, width = 2, color = blue
# Object 2: instance of type rectangle; data attributes: height = 1, width = 3, color = yellow

# %%
class Circle(object):
    def _init_ (self, radius,color):                    # these are the set data attributes (do not change); use methods below to play with output
        self.radius = radius;
        self.color = color;
    
        

    def add_radius(self,r):
        self.radius = self.radius + r                   # method used to add r to the radius
        return(self.radius)

RedCircle = Circle(3,'red')

RedCircle.radius


# 
# to draw the object: RedCircle.drawCircle()

# %%
sample_test = "This is a test, test! Has all? the . punctuation been removed?" 

class analysedText(object):
    
    def __init__ (self, text):                          # creating an instance of the class (called an object); _init_ is a constructor; generally every class has a constructor
        self.text = text
        self.text = text.lower()
        to_remove = {",":" ", "!":" ", "?":" ", ".":" "}
        for char in to_remove.keys():
            self.text = self.text.replace(char, to_remove[char])








#print(sample_test)
#print(analysedText(sample_test).text)

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def add(self, other):
        self.x = self.x + other.x
        self.y = self.y + other.y

pt1 = Point(1,2)
pt2 = Point(3,4)

pt1.add(pt2)
Point.add(pt1, pt2)
print(pt1.x, pt1.y)


def add(num1, num2):
    return num1 + num2

# print(add(1,2))

# Class is the declaration of code! It's

# %%
class TextConverter(object):
    def __init__ (self, text):                          # creating an instance of the class (called an object); _init_ is a constructor; generally every class has a constructor
        self.text = text

    def convert(self):
        text = self.text.lower()
        to_remove = {",":" ", "!":" ", "?":" ", ".":" "}
        for char in to_remove.keys():
            text = text.replace(char, to_remove[char])
        return text

sample_text = "This is a test, test! Has all? the . punctuation been removed?" 
c = TextConverter(sample_test)
converted_text = c.convert()


print(sample_text)
print(converted_text)
#print(analysedText(sample_test).text)

# %%
class analysedText(object):
    
    def __init__ (self, text):
        self.text = text
        fmtText = text.replace('.','').replace('!','').replace('?','').replace(',','')
        fmtText = fmtText.lower()
        self.fmtText = fmtText
        # self.text = text.lower()
        # fmtText = self.text
        # to_remove = {",":" ", "!":" ", "?":" ", ".":" "}
        # for char in to_remove.keys():
        #     fmtText = fmtText.replace(char, to_remove[char])
        # return(fmtText)
        
        # TODO: Remove the punctuation from <text> and make it lower case.
        # TODO: Assign the formatted text to a new attribute called "fmtText"
        
        pass  

    def freqAll(self):
        
        wordList = fmtText.split()          # split text into words
        freq_words = {}                     # create a dictionary
        for word in set(wordList):          # use set to remove duplicates in list
            freq_words = wordList.count(word)
        return freq_words


        # dic = {}
        # for item in fmtText():
        #     if item in dic:
        #         dic[item] += 1
        #     else:
        #         dic[item] = 1
        # return sorted(dic.items())


        # TODO: Split the text into a list of words  

        # TODO: Create a dictionary with the unique words in the text as keys
        # and the number of times they occur in the text as values
      
        pass # return the created dictionary
    
    def freqOf(self, word):
        freq_Dict = self.freqAll()
        if word in freq_Dict:
            return freq_Dict[word]
        else:
            return 0


        # word.self = word
        # word = fmtText
        # num_unique_names = set(fmtText)
        # return(len(set(num_unique_names)))


        # TODO: return the number of occurrences of <word> in <fmtText>

        pass

# %%
# Example from https://pynative.com/python-instance-variables/
# Instance variables are declared inside a method using the self keyword.
# We use a constructor to define and initialize the instance variables
# Below, two instance variables (name and age), are created in the Student class

class Student:
    # constructor
    def __init__(self, name, age):
        # Instance variable
        self.name = name
        self.age = age

# create first object
s1 = Student("Jessa", 20)

# access instance variable
print('Object 1')
print('Name:', s1.name)
print('Age:', s1.age)

# create second object
s2= Student("Kelly", 10)

# access instance variable
print('Object 2')
print('Name:', s2.name)
print('Age:', s2.age)

# %% [markdown]
# Constructors in python
# - in object-oriented programming (OOP), a constructor is a special method used to create and initialize an object of a class; this method is defined in the class
# - the constructor is executed automatically at the time of object creation
# - the primary use of a constructor is to declare and initialize data member/instance variables of a class
# - the constructor contains a collection of statements (i.e., instructions) that executes at the time of object creation to initialize the attributes of an object
# - eg. when we execute: obj = Sample()   ; Python gets to know that obj is an object of class Sample and calls the constructor of that class to create an object
# - in Python, Object creation is divided into two parts in Object Creation and Object initialization
#             (Note: In Python, internally, the __new__ is the method that creates the object, and __del__ method is called to destroy the object when the reference count for that object becomes zero)
#
#     - Internally, the __new__ is the method that creates the object
#     - And, using the __init__() method we can implement constructor to initialize the object
#
# - Syntax of a constructor:
# def__init__(self):
#     # body of the constructor
#
#     def: The keyword is used to define function
#     __init__() Method: it is a reserved method; gets called as soon as an object of a class is instantiated
#     self: The first argument self refers to the current object. It binds the instance to the __init__() method. It's usually named self to follow the naming conventions.
#     Note: the __init__() method arguments are optional. We can define a constructor with any number of arguments

# %%
# example from https://pynative.com/python-constructors/

class Student:

    # constructor
    # initialize instance variable
    def __init__(self, name):
        print('Inside Constructor')
        self.name = name
        print('All variables initialized')

    # instance Method
    def show(self):
        print('Hello, my name is', self.name)


# create object using constructor
s1 = Student('Emma')
s1.show()
